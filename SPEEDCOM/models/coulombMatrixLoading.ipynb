# %%
import NNModels
from NNModels import Descriptors
import rdkit

# %% [markdown]
# ### Set the molecule

# %%
smiles = 'C1=CC=CC=C1'

# %% [markdown]
# ### Initialize the Descriptor class

# %%
des_engine = Descriptors(smiles)

# %% [markdown]
# ### Using the Descriptor class

# %%
des_engine.get_coulomb_matrix()
# Out:
# array([[ 5.48400114,  2.78966004,  1.96879222,  1.3813058 ,  1.2369328 ,
#          1.38131041,  1.96880532,  1.8362525 ,  1.0840032 ,  0.94730492,
#          1.08399869,  1.83623187,  0.5       ,  0.56017032,  0.56017001,
#          0.26168431,  0.38090484,  0.24296191,  0.15527524,  0.17837898,
#          0.17232607,  0.14392224,  0.14877149,  0.1487714 ,  0.15527472,
#          0.17837794,  0.17232544,  0.26168371,  0.24295858,  0.3808978 ],
#        [ 1.83623389,  1.96879333,  1.38130638,  1.23693284,  1.38131004,
#          1.96880475,  2.78966053,  5.48400554,  1.83625325,  1.08400297,
#          0.94730494,  1.08399952,  0.26168431,  0.24295861,  0.38089824,
#          0.5       ,  0.56017088,  0.56017044,  0.24296169,  0.38090498,
#          0.26168532,  0.17232604,  0.17837892,  0.1552752 ,  0.1487715 ,
#          0.14877139,  0.14392225,  0.17232586,  0.15527472,  0.17837794],
#        [ 5.48192161,  2.76345693,  1.76254728,  1.31219479,  1.2368553 ,
# ...

# %% [markdown]
# ### Re-initializing the Descriptor class with a different molecule

# %%
smiles2 = 'CC1=C(C(=C(C(=C1C)C)C)C)C'

# %%
des_engine.set_molecule(smiles2)

# %%
des_engine.get_coulomb_matrix()
# Out:
# array([[ 5.48192642,  2.76345869,  2.21483967,  1.47007535,  1.23685637,
#          1.3121951 ,  1.76254687,  1.52316544,  1.01896887,  0.94624195,
#          1.17924938,  2.31240483,  0.5       ,  0.56017022,  0.57751467,
#          0.20090534,  0.27369005,  0.24296144,  0.16876714,  0.15527469,
#          0.15155647,  0.14831318,  0.14365179,  0.14877108,  0.17837856,
#          0.20548005,  0.16876711,  0.38090015,  0.27369026,  0.45069342],
#        [ 5.48192365,  2.76345556,  1.76254522,  1.31219383,  1.23685531,
#          1.4700742 ,  2.21483781,  2.31240964,  1.17924833,  0.94624137,
#          1.0189682 ,  1.52316294,  0.57751467,  0.56017036,  0.5       ,
#          0.27369043,  0.45069219,  0.38090434,  0.20547998,  0.17837799,
#          0.1687672 ,  0.14365161,  0.14831319,  0.14877099,  0.15527487,
#          0.16876701,  0.1515562 ,  0.24295945,  0.20090542,  0.27369056],
#        [ 1.52316247,  1.76254412,  1.31219297,  1.23685485,  1.47007425,
# ...
