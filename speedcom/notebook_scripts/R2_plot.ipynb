# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.DataFrame()

# %%
df['predictor'] = ['$\lambda_{abs}$', '$\epsilon$', '$\lambda_{em}$', '$QY$']

# %%
df['SMILES--LSTM'] = [0.55, 0.55, 0, 0.42]

# %%
df['SMILES--Conv1D'] = [0.73, 0, 0.77, 0.08]

# %%
df['CM--DNN'] = [0.33, 0.48, 0, 0.24]

# %%
df['FP--Conv1D'] = [0.32, 0.10, 0, 0]

# %%
df
# Out:
#          predictor  SMILES--LSTM  SMILES--Conv1D  CM--DNN  FP--Conv1D
# 0  $\lambda_{abs}$          0.55            0.73     0.33        0.32
# 1       $\epsilon$          0.55            0.00     0.48        0.10
# 2   $\lambda_{em}$          0.00            0.77     0.00        0.00
# 3             $QY$          0.42            0.08     0.24        0.00

# %%
ax = df.plot.bar(x='predictor', y=['SMILES--LSTM','SMILES--Conv1D','CM--DNN','FP--Conv1D'], \
                  legend=False,figsize=(16,5), fontsize=20, width=0.8)
#plt.legend(['in Gas Phase', 'in Glycerol'], fontsize=15)
ax.set_ylim([0, 1])
ax.set_xlabel('Predictors', fontsize=20)
ax.set_ylabel('$R^2$ of the testing sets', fontsize=20)
ax.set_xticklabels(list(df['predictor']), fontweight='semibold', rotation=None)
ax.legend(['SMILES--LSTM','SMILES--Conv1D','CM--DNN','FP--Conv1D'], fontsize=15, loc='upper right')

for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x()+i.get_width()/2, i.get_height()+0.02, \
            str(i.get_height()), fontsize=15,
                color='k', ha='center', va='bottom', fontweight='semibold')
    
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)
    
plt.savefig('R2_plot.png', bbox_inches='tight')
